# %% [markdown]
# <a href="https://colab.research.google.com/github/PanoEvJ/summarization_RLHF/blob/main/evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ppo_return_mean = [ 0.05318493768572807, 0.09490420669317245, 0.12642419338226318]
ppo_advantages_mean = [0.0018993918783962727, -5.807960405945778e-05, 0.0011868876172229648]
objective_kl = [0.0,-0.08673879504203796, -0.9768379926681519]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.array(ppo_return_mean)
s = [1,2,3]

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='episodes', ylabel='mean return',
       title='Policy optimization')
# ax.grid()

fig.savefig("test.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
s = [1,2,3]

fig, axs = plt.subplots(1, 3, figsize=(22,6))

axs[0].set(xlabel='episodes', ylabel='', title='Mean return')
axs[0].plot(np.array(ppo_return_mean), s)

axs[1].set(xlabel='episodes', ylabel='', title='Mean advantage')
axs[1].plot(np.array(ppo_advantages_mean), s)

axs[2].set(xlabel='episodes', ylabel='', title='Objective KL')
axs[2].plot(np.array(objective_kl), s)
# ax.grid()

fig.savefig("ppo_train.png")
fig.suptitle("Policy Traininig with PPO")
plt.show()
